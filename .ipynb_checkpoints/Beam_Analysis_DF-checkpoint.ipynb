# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mplhep as hep
from iminuit import Minuit
from iminuit.cost import LeastSquares
import pickle
import uproot as ur
import matplotlib.colors as mcolors
import numpy as np
from scipy.optimize import curve_fit

# %%
data_df = pd.read_pickle("JLab_DF.pkl")
sim_df = pd.read_pickle("e+5GeV_ct_DF.pkl") 
sim_df["energy_MIP"] = sim_df["energy_MIP"] / (0.00117) 
hit_threshold = 1

# %%
min_ts = data_df['TS'].min()
data_df['TS'] = data_df['TS'] - min_ts

# %%
# Choose which event and layer to display
selected_event = 100
selected_layer = 11  # Use 0 if layer is int, or 0.0 if it's float in your data

# Filter the DataFrame
subset = sim_df[(sim_df['event'] == selected_event) & (sim_df['layer'] == selected_layer)]
#subset = data_df[(sim_df['event'] == selected_event) & (data_df['layer'] == selected_layer)]

# Check if there's data to plot
if subset.empty:
    print(f"No data found for event {selected_event} and layer {selected_layer}.")
else:
    x = subset['x']
    y = subset['y']
    c = subset['energy_MIP']

    # Remove non-positive values (log scale can't handle them)
    mask = c >= 0
    x = x[mask]
    y = y[mask]
    c = c[mask]

    plt.figure(figsize=(6, 6))
    scatter = plt.scatter(
        x, y, c=c, cmap='viridis', s=100, edgecolors='k'
    )
    #norm=mcolors.LogNorm()
    cbar = plt.colorbar(scatter)
    cbar.set_label('Energy [MIP]')
    plt.title(f'Energy [MIP] for Event {selected_event}, Layer {selected_layer}')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.axis('equal')
    plt.xlim(-150, 150)
    plt.ylim(-150, 150)
    plt.grid(True)
    
    plt.show()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
unique_ts = np.unique(data_df['TS'])
time_s = unique_ts  # convert from µs to seconds

# Step 2: Define time bins (60-second intervals)
bin_width = 60  # seconds
min_time = np.floor(time_s.min())
max_time = np.ceil(time_s.max())
bins = np.arange(min_time, max_time + bin_width, bin_width)

# Step 3: Histogram counts per 60-second bin
counts, bin_edges = np.histogram(time_s, bins=bins)
bin_centers = 0.5 * (bin_edges[1:] + bin_edges[:-1])

# Step 4: Error is sqrt(counts) assuming Poisson stats
errors = np.sqrt(counts)

# Step 5: Plot
plt.figure(figsize=(10, 5))
plt.errorbar(bin_centers, counts/60, yerr=errors/60, fmt='o-', markersize=4, capsize=3)
plt.xlabel("Time (s)")
plt.ylabel("Event Rate (Hz)")
plt.title("Event Rate")

plt.tight_layout()
plt.show()

# %%
def configure_plotting():
    plt.rcParams['figure.facecolor'] = 'white'
    plt.rcParams['savefig.facecolor'] = 'white'
    plt.rcParams['savefig.bbox'] = 'tight'
    hep.style.use(hep.style.CMS)

def event_energy(data_df, threshold=0.5):
    filtered_df = data_df[data_df['energy_MIP'] > threshold]
    energy_sum = filtered_df.groupby('event')['energy_MIP'].sum()
    return energy_sum.values
    
def layer_energy(data_df, layer, threshold=0.5):
    # Filter by energy threshold and layer
    filtered_df = data_df[(data_df['energy_MIP'] > threshold) & (data_df['layer'] == layer)]

    # Group by 'event' and sum 'energy_MIP'
    energy_sum = filtered_df.groupby('event')['energy_MIP'].sum()

    # Return just the values as a NumPy array
    return energy_sum.values

# %%
def filter_event_energy(data_df, event_energy_threshold, hit_threshold=0.5):
    # Step 1: Filter hits above the hit energy threshold
    filtered_hits = data_df[data_df['energy_MIP'] > hit_threshold]

    # Step 2: Sum energy per event
    event_energy_sum = (
        filtered_hits.groupby('event')['energy_MIP']
        .sum()
        .reset_index(name='total_energy')
    )

    # Step 3: Keep only events with total energy above the event_energy_threshold
    selected_events = (event_energy_sum[event_energy_sum['total_energy'] > event_energy_threshold]['event'])

    # Step 4: Filter original data to include only selected events
    filtered_df = data_df[data_df['event'].isin(selected_events)]

    return filtered_df
    
#evt_energy_data = event_energy(sim_df, hit_threshold)
#print(len(evt_energy_data))
data_df = filter_event_energy(data_df, 25)
sim_df = filter_event_energy(sim_df, 25)
#evt_energy_data = event_energy(sim_df, hit_threshold)
#print(len(evt_energy_data))

# %%
configure_plotting()

def gaussian(x, A, mu, sigma):
    return A * np.exp(-(x - mu)**2 / (2 * sigma**2))
    
# Helper function to fit and normalize histogram
def fit_and_plot(evt_energy, label, color):
    counts, bin_edges = np.histogram(evt_energy, bins=200, range=[0, 250])
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

    # Normalize
    total = np.sum(counts)
    counts = counts / total
    errors = np.sqrt(counts * total) / total  # Poisson errors normalized

    # Initial guess for Gaussian parameters: [amplitude, mean, std dev]
    A_guess = max(counts)
    mu_guess = bin_centers[np.argmax(counts)]
    sigma_guess = np.std(evt_energy[evt_energy<200])
    try:
        popt, _ = curve_fit(gaussian, bin_centers, counts, p0=[A_guess, mu_guess, sigma_guess])
        A_fit, mu_fit, sigma_fit = popt
        resolution = sigma_fit / mu_fit
        fit_label = f"{label} ($\\mu$ = {mu_fit:.1f}, res = {resolution*100:.1f}%)"
        plt.plot(bin_centers, gaussian(bin_centers, *popt), color=color, linestyle='--')
    except RuntimeError:
        fit_label = f"{label} (fit failed)"
    
    # Plot data with error bars
    plt.errorbar(bin_centers, counts, yerr=errors, fmt='o', label=fit_label, color=color)

# Run for both data and sim
evt_energy_data = event_energy(data_df, hit_threshold)
evt_energy_sim = event_energy(sim_df, hit_threshold)
print(np.mean(evt_energy_sim))
plt.figure(figsize=(8, 5))
fit_and_plot(evt_energy_data, "Data", color='tab:blue')
fit_and_plot(evt_energy_sim, "Sim", color='tab:orange')
plt.ylim(0,0.05)
plt.legend(fontsize=15, loc="upper right")
plt.title("Event Energy")
plt.xlabel("Energy [MIP]")
plt.ylabel("Count (Normalized)")
plt.savefig('plots/event_energy.png', bbox_inches='tight')
plt.show()
dat_evts = len(evt_energy_data)
sim_evts = len(evt_energy_sim)
# Out:
# 105.71385248080377

# %%
# Combine all hits from all events
all_hits_data = data_df["energy_MIP"].to_numpy()
all_hits_sim = sim_df["energy_MIP"].to_numpy()

def plot_all_hits(evt_hits, n_events, label, color, bins=200, hist_range=(0, 30)):
    # Compute histogram
    counts, bin_edges = np.histogram(evt_hits, bins=bins, range=hist_range)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

    # Normalize to number of events
    counts = counts / n_events
    errors = np.sqrt(counts * n_events) / n_events  # Poisson errors scaled

    plt.errorbar(bin_centers, counts, yerr=errors, fmt='o', label=label, color=color)
    plt.yscale("log")
# Plot
plt.figure(figsize=(8, 6))

plot_all_hits(all_hits_data, dat_evts, label="Data", color="tab:blue")
plot_all_hits(all_hits_sim, sim_evts, label="Simulation", color="tab:orange")

plt.xlabel("Hit Energy (MIP)")
plt.ylabel("Counts (normalized)")
plt.title("All Hits")
plt.legend()
plt.tight_layout()
plt.show()

# %%
max_energy_data = data_df.groupby("event")["energy_MIP"].max().to_numpy()
max_energy_sim = sim_df.groupby("event")["energy_MIP"].max().to_numpy()

def plot_histogram(evt_energy, label, color, bins=200, hist_range=(0, 30)):
    # Compute histogram
    counts, bin_edges = np.histogram(evt_energy, bins=bins, range=hist_range)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

    # Normalize counts
    total = np.sum(counts)
    counts = counts / total
    errors = np.sqrt(counts * total) / total  # Poisson errors normalized

    # Plot with error bars
    plt.errorbar(bin_centers, counts, yerr=errors, fmt='o', label=label, color=color)
    
configure_plotting()
plt.figure(figsize=(8, 6))

plot_histogram(max_energy_data, label="Data", color="tab:blue")
plot_histogram(max_energy_sim, label="Simulation", color="tab:orange")

plt.xlabel("Max energy per event (MIP)")
plt.ylabel("Normalized counts")
plt.title("Max Hit Energy Distribution")
plt.legend()
plt.tight_layout()
plt.show()

# %%
def plot_channel_energy_histograms(data_df, sim_df, layer, threshold, bins=100, hist_range=(0, 20)):
    
    # Filter data for the specified layer
    data_layer = data_df[data_df['layer'] == layer]
    sim_layer = sim_df[sim_df['layer'] == layer]

    # Count number of events (for normalization)
    dat_evts = len(data_layer['event'].unique())
    sim_evts = len(sim_layer['event'].unique())

    # Create 5x5 subplots (25 channels)
    fig, axes = plt.subplots(5, 5, figsize=(20, 20), sharex=True, sharey=True)
    axes = axes.flatten()

    for ch in range(25):  # Channels 0–24
        # Get energies for this channel above threshold
        data_energy = data_layer[(data_layer['layer_ch'] == ch) & (data_layer['energy_MIP'] > threshold)]['energy_MIP']
        sim_energy = sim_layer[(sim_layer['layer_ch'] == ch) & (sim_layer['energy_MIP'] > threshold)]['energy_MIP']

        # Compute histograms
        data_counts, bin_edges = np.histogram(data_energy, bins=bins, range=hist_range)
        sim_counts, _ = np.histogram(sim_energy, bins=bin_edges)

        # Normalize by total events
        if dat_evts > 0:
            data_norm = data_counts / dat_evts
            data_errors = np.sqrt(data_counts) / dat_evts
        else:
            data_norm = np.zeros_like(data_counts)
            data_errors = np.zeros_like(data_counts)

        if sim_evts > 0:
            sim_norm = sim_counts / sim_evts
            sim_errors = np.sqrt(sim_counts) / sim_evts
        else:
            sim_norm = np.zeros_like(sim_counts)
            sim_errors = np.zeros_like(sim_counts)

        bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

        # Plot on the correct subplot
        ax = axes[ch]
        ax.errorbar(bin_centers, data_norm, yerr=data_errors, fmt='o', color='tab:blue', label=f'Ch {ch} Data')
        ax.errorbar(bin_centers, sim_norm, yerr=sim_errors, fmt='-', color='tab:orange', label=f'Ch {ch} Sim')
        ax.legend()
        ax.axvline(x=hit_threshold, color='red', linestyle='--', lw=1)
        #ax.set_title(f'Ch {ch}')
        ax.set_yscale("log")
        ax.set_ylim(0.01, 0.3)
        if ch >= 20:  # last row
            ax.set_xlabel('Energy (MIP)')
        if ch % 5 == 0:  # first column
            ax.set_ylabel('Norm. Counts')

    # Hide extra axes if there are less than 25 channels
    for extra_ax in axes[25:]:
        extra_ax.axis('off')

    fig.suptitle(f'Energy Distributions for Layer {layer}', fontsize=18)
    plt.tight_layout(pad=0.0)
    #plt.tight_layout(rect=[0, 0, 1.5, 1])
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.savefig(f'plots/hits_layer_{i}.png', bbox_inches='tight')
    plt.show()

# %%
for i in range(15):
    plot_channel_energy_histograms(data_df, sim_df, i, threshold=0)

# %%
def plot_energy_histograms_comparison(data_df, sim_df, threshold, bins=500, hist_range=(0, 40)):
    # Drop NaNs and get sorted unique layers from the *data_df* only
    unique_layers = sorted(data_df['layer'].dropna().unique())
    n_layers = len(unique_layers)

    # Set up subplots
    ncols = 5
    nrows = int(np.ceil(n_layers / ncols))
    fig, axes = plt.subplots(nrows, ncols, figsize=(ncols * 5, nrows * 4), sharex=True, sharey=True)
    axes = axes.flatten()

    for i, layer in enumerate(unique_layers):
        # Get event energy sums above threshold for both real and simulated data
        data_energy = layer_energy(data_df, layer, threshold)
        sim_energy = layer_energy(sim_df, layer, threshold)

        # Compute histograms
        data_counts, bin_edges = np.histogram(data_energy, bins=bins, range=hist_range)
        sim_counts, _ = np.histogram(sim_energy, bins=bin_edges)

        # Normalize by total counts (events)
        if data_counts.sum() > 0:
            data_norm = data_counts / dat_evts
            data_errors = np.sqrt(data_counts) / dat_evts
        else:
            data_norm = data_counts
            data_errors = data_counts

        if sim_counts.sum() > 0:
            sim_norm = sim_counts / sim_evts
            sim_errors = np.sqrt(sim_counts) / sim_evts
        else:
            sim_norm = sim_counts
            sim_errors = sim_counts

        bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

        ax = axes[i]
        ax.errorbar(bin_centers, data_norm, yerr=data_errors, fmt='o', label=f'Layer {int(layer)} Data', color='tab:blue')
        ax.errorbar(bin_centers, sim_norm, yerr=sim_errors, fmt='-', label=f'Layer {int(layer)} Sim', color='tab:orange')

        #ax.set_ylim(0,0.1)
        ax.legend()
        if layer >= 5:  # last row
            ax.set_xlabel('Energy (MIP)')
        if layer % 5 == 0:  # first column
            ax.set_ylabel('Norm. Counts')

    # Hide unused subplots
    for j in range(i + 1, len(axes)):
        axes[j].axis('off')
  

    plt.tight_layout(pad=0.0)
    #plt.tight_layout(rect=[0, 0, 1.5, 1])
    plt.subplots_adjust(wspace=0, hspace=0)
    plt.savefig('plots/layer_energy.png', bbox_inches='tight')
    plt.show()
hit_threshold = 1.0
plot_energy_histograms_comparison(data_df=data_df, sim_df=sim_df, threshold=hit_threshold)

# %%
def event_cog(df, threshold):
    # Filter for hits above threshold and with finite x, y, z
    mask = (
        (df['energy_MIP'] > threshold) &
        df['x'].notna() & df['y'].notna() & df['z'].notna()
    )
    filtered = df[mask].copy()
    
    # Compute energy-weighted positions
    filtered['xw'] = filtered['x'] * filtered['energy_MIP']
    filtered['yw'] = filtered['y'] * filtered['energy_MIP']
    filtered['zw'] = filtered['z'] * filtered['energy_MIP']

    # Group by event and compute weighted average
    grouped = filtered.groupby('event').agg(
        x_cog = ('xw', lambda x: x.sum()),
        y_cog = ('yw', lambda x: x.sum()),
        z_cog = ('zw', lambda x: x.sum()),
        e_sum = ('energy_MIP', 'sum')
    )

    # Divide by total energy to get center of gravity
    grouped['x_cog'] /= grouped['e_sum']
    grouped['y_cog'] /= grouped['e_sum']
    grouped['z_cog'] /= grouped['e_sum']

    # Drop total energy column
    grouped = grouped.drop(columns=['e_sum']).reset_index()

    return grouped

# %%
def fit_gaussian_and_plot(ax, bin_centers, counts, errors, label, color, linestyle='-'):
    try:
        A_guess = np.max(counts)
        mu_guess = bin_centers[np.argmax(counts)]
        sigma_guess = np.std(bin_centers, ddof=1)
        sigma_guess = 5
        popt, _ = curve_fit(gaussian, bin_centers, counts, p0=[A_guess, mu_guess, sigma_guess])
        A_fit, mu_fit, sigma_fit = popt
        resolution = sigma_fit / abs(mu_fit) if mu_fit != 0 else np.nan

        fit_label = f"{label} (μ = {mu_fit:.1f}, σ = {sigma_fit:.1f})"
        ax.plot(bin_centers, gaussian(bin_centers, *popt), color=color, linestyle=':')
    except RuntimeError:
        fit_label = f"{label} (fit failed)"
    ax.errorbar(bin_centers, counts, yerr=errors, label=fit_label, fmt=linestyle, color=color, capsize=2)

def plot_event_cog_distributions(data_df, sim_df, threshold=0.5, bins=100, ranges=None):
    """
    Plot x, y, z CoG histograms for data_df and sim_df with Gaussian fits and resolution.
    """
    cog_data = event_cog(data_df, threshold)
    cog_sim = event_cog(sim_df, threshold)

    if ranges is None:
        ranges = {
            'x': (-50, 50),
            'y': (-50, 50),
            'z': (0,  300)
        }

    fig, axs = plt.subplots(1, 3, figsize=(18, 5))

    for i, coord in enumerate(['x_cog', 'y_cog', 'z_cog']):
        ax = axs[i]
        axis_label = coord[0]
        hist_range = ranges[axis_label]

        # Data histogram
        counts_data, bins_data = np.histogram(cog_data[coord], bins=bins, range=hist_range)
        bin_centers = (bins_data[:-1] + bins_data[1:]) / 2
        counts_data = counts_data / dat_evts
        errors_data = np.sqrt(counts_data * dat_evts) / dat_evts

        # Sim histogram
        counts_sim, bins_sim = np.histogram(cog_sim[coord], bins=bins, range=hist_range)
        counts_sim = counts_sim / sim_evts
        errors_sim = np.sqrt(counts_sim * sim_evts) / sim_evts

        # Fit and plot both
        fit_gaussian_and_plot(ax, bin_centers, counts_data, errors_data, "Data", color='tab:blue', linestyle='o')
        fit_gaussian_and_plot(ax, bin_centers, counts_sim,  errors_sim,  "Sim",  color='tab:orange', linestyle='-')

        ax.set_title(f'{axis_label.upper()} Center of Gravity [PRELIMINARY]', fontsize=18)
        ax.set_xlabel(f'{axis_label.upper()} Position (mm)', fontsize=18)
        ax.set_ylabel('Normalized Counts', fontsize=18)
        ax.legend(fontsize=15, loc="upper right")
        ax.set_ylim(0,0.25)
    plt.tight_layout()
    plt.savefig('plots/cog_distributions.png', bbox_inches='tight')
    plt.show()

plot_event_cog_distributions(data_df=data_df, sim_df=sim_df, threshold=hit_threshold)

# %%
def layer_xy_cog(df, layer_num, threshold):
    df_filtered = df[
        (df['layer'] == layer_num) &
        (df['energy_MIP'] > threshold) &
        df[['x', 'y']].notna().all(axis=1)
    ]
    
    def compute_cog(group):
        total_energy = group['energy_MIP'].sum()
        if total_energy == 0:
            return pd.Series({'x_cog': np.nan, 'y_cog': np.nan})
        x_cog = (group['x'] * group['energy_MIP']).sum() / total_energy
        y_cog = (group['y'] * group['energy_MIP']).sum() / total_energy
        return pd.Series({'x_cog': x_cog, 'y_cog': y_cog})

    return df_filtered.groupby('event').apply(compute_cog, include_groups=False)

# %%
def event_hit_multiplicity(data_df, threshold=0.5):
    # Filter hits above the threshold
    filtered_df = data_df[data_df['energy_MIP'] > threshold]

    # Count hits per event
    multiplicity_series = filtered_df.groupby('event').size()

    # Return as NumPy array
    return multiplicity_series.values

fig, axs = plt.subplots(1, 1, figsize=(5, 5))
evt_mult = event_hit_multiplicity(data_df, hit_threshold)
counts, bin_edges = np.histogram(evt_mult, bins=75, range=[0, 75])
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
errors = np.sqrt(counts)
counts = counts / dat_evts
errors = errors / dat_evts
plt.errorbar(bin_centers, counts, yerr=errors, fmt='o', label="Data")

evt_mult = event_hit_multiplicity(sim_df, hit_threshold)
counts, bin_edges = np.histogram(evt_mult, bins=75, range=[0, 75])
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
errors = np.sqrt(counts)
counts = counts / sim_evts
errors = errors / sim_evts
plt.errorbar(bin_centers, counts, yerr=errors, fmt='-',label="Sim")
plt.title("Event Hit Multiplicity", fontsize = 20)
plt.xlabel("Hit Multiplicity [PRELIMINARY]", fontsize = 20)
plt.ylabel("Count (Normalized)", fontsize = 20)
plt.legend()
plt.savefig('plots/hit_multiplicity.png', bbox_inches='tight')
plt.show()

# %%
def layer_event_hit_multiplicity(data_df, layer, threshold=0.5):
    # Filter hits above the threshold and for the specified layer
    filtered_df = data_df[
        (data_df['energy_MIP'] > threshold) & 
        (data_df['layer'] == layer)
    ]

    # Count hits per event in that layer
    multiplicity_series = filtered_df.groupby('event').size()

    # Return as NumPy array
    return multiplicity_series.values

def plot_hit_multiplicity_by_layer(data_df, sim_df, threshold=0.5, bins=15, max_layers=None):
    # Identify valid (non-NaN) unique layers
    layers = sorted(data_df['layer'].dropna().unique())
    if max_layers:
        layers = layers[:max_layers]

    n_layers = len(layers)
    ncols = 4
    nrows = int(np.ceil(n_layers / ncols))
    fig, axes = plt.subplots(nrows, ncols, figsize=(ncols * 4, nrows * 3), tight_layout=True)

    for idx, layer in enumerate(layers):
        row, col = divmod(idx, ncols)
        ax = axes[row, col] if nrows > 1 else axes[col]

        # Get multiplicity arrays
        mult_data = layer_event_hit_multiplicity(data_df, layer, threshold)
        mult_sim = layer_event_hit_multiplicity(sim_df, layer, threshold)

        # Histogram data
        counts_data, bins_data = np.histogram(mult_data, bins=bins, range=(0, 15))
        counts_sim, bins_sim = np.histogram(mult_sim, bins=bins, range=(0, 15))

        # Normalize
        counts_data = counts_data / len(mult_data) if len(mult_data) > 0 else counts_data
        counts_sim = counts_sim / len(mult_sim) if len(mult_sim) > 0 else counts_sim

        bin_centers = (bins_data[:-1] + bins_data[1:]) / 2

        # Error bars
        errors_data = np.sqrt(counts_data) / len(mult_data) if len(mult_data) > 0 else np.zeros_like(counts_data)
        errors_sim = np.sqrt(counts_sim) / len(mult_sim) if len(mult_sim) > 0 else np.zeros_like(counts_sim)

        # Plot
        ax.errorbar(bin_centers, counts_data, yerr=errors_data, fmt='o', label='Data', color='blue')
        ax.errorbar(bin_centers, counts_sim, yerr=errors_sim, fmt='-', label='Sim', color='orange')
        ax.set_title(f'Layer {int(layer)}', fontsize=20)
        ax.set_xlabel('Hit Multiplicity', fontsize=18)
        ax.set_ylabel('Normalized Counts', fontsize=16)
        ax.legend(fontsize=10)
        ax.set_ylim(0,1) 

    # Hide any unused subplots
    for j in range(idx + 1, nrows * ncols):
        row, col = divmod(j, ncols)
        fig.delaxes(axes[row, col] if nrows > 1 else axes[col])
    plt.savefig('plots/hit_layer_multiplicity.png', bbox_inches='tight')
    plt.show()

plot_hit_multiplicity_by_layer(data_df=data_df, sim_df=sim_df, threshold=hit_threshold)

# %%
def compute_all_event_moment_matrices(data_df, e_cut=0.5):
    def compute_moment_matrix(group):
        energies = group['energy_MIP'].to_numpy(dtype=np.float32)
        positions = group[['x', 'y', 'z']].to_numpy(dtype=np.float32)

        mask = energies > e_cut
        if np.count_nonzero(mask) == 0:
            
            return np.full((3, 3), np.nan, dtype=np.float32)

        energies = energies[mask]
        positions = positions[mask]

        # Check for NaNs or infs in energies or positions
        if np.any(np.isnan(energies)) or np.any(np.isinf(energies)):
            # Debug print - remove or comment out after debugging

            return np.full((3, 3), np.nan, dtype=np.float32)

        if np.any(np.isnan(positions)) or np.any(np.isinf(positions)):

            return np.full((3, 3), np.nan, dtype=np.float32)

        energy_sum = energies.sum()
        if energy_sum <= 1e-10:
            return np.full((3, 3), np.nan, dtype=np.float32)

        # Explicit check before division
        if energy_sum == 0:
            return np.full((3, 3), np.nan, dtype=np.float32)

        weights = energies / energy_sum

        # Extra check: weights should not contain NaNs or infs
        if np.any(np.isnan(weights)) or np.any(np.isinf(weights)):
            return np.full((3, 3), np.nan, dtype=np.float32)

        if np.sum(weights) == 0:
            return np.full((3, 3), np.nan, dtype=np.float32)

        cog = np.average(positions, axis=0, weights=weights)
        deltas = positions - cog

        moment_matrix = np.einsum('i,ij,ik->jk', weights, deltas, deltas) / np.sum(weights)
        return moment_matrix

    return data_df.groupby('event', group_keys=False).apply(compute_moment_matrix)

def compute_all_cluster_orientations(moment_matrices):
    """
    Computes orientation information for a Series of 3x3 moment matrices.
    Ensures principal axis always points forward (z >= 0).

    Parameters:
        moment_matrices: pd.Series where each entry is a (3, 3) ndarray (moment matrix)

    Returns:
        pd.DataFrame with columns:
            - theta: angle from z-axis [0, π/2]
            - phi: angle in x-y plane
            - principal_axis_x, y, z: components of principal axis
            - eigenvalues: array of eigenvalues
    """
    results = []

    for event_id, matrix in moment_matrices.items():
        if matrix is None or np.isnan(matrix).any():
            results.append({
                'event': event_id,
                'theta': np.nan,
                'phi': np.nan,
                'principal_axis_x': np.nan,
                'principal_axis_y': np.nan,
                'principal_axis_z': np.nan,
                'eigenvalues': [np.nan, np.nan, np.nan]
            })
            continue

        try:
            eigenvalues, eigenvectors = np.linalg.eigh(matrix)
            principal_index = np.argmax(eigenvalues)
            principal_axis = eigenvectors[:, principal_index]
            principal_axis /= np.linalg.norm(principal_axis)

            # Flip axis to point forward in z
            if principal_axis[2] < 0:
                principal_axis = -principal_axis

            x, y, z = principal_axis
            theta = np.arccos(z)
            phi = np.arctan2(y, x)

            results.append({
                'event': event_id,
                'theta': theta,
                'phi': phi,
                'principal_axis_x': x,
                'principal_axis_y': y,
                'principal_axis_z': z,
                'eigenvalues': eigenvalues
            })
        except Exception:
            results.append({
                'event': event_id,
                'theta': np.nan,
                'phi': np.nan,
                'principal_axis_x': np.nan,
                'principal_axis_y': np.nan,
                'principal_axis_z': np.nan,
                'eigenvalues': [np.nan, np.nan, np.nan]
            })

    return pd.DataFrame(results).set_index('event')

# %%
moment_matrices_data = compute_all_event_moment_matrices(data_df, e_cut=hit_threshold)
moment_matrices_sim = compute_all_event_moment_matrices(sim_df, e_cut=hit_threshold)
orient_data = compute_all_cluster_orientations(moment_matrices_data)
orient_sim = compute_all_cluster_orientations(moment_matrices_sim)
# Out:
# /var/folders/78/mghq7lpd3rbcbtn434kbwgdw0000gn/T/ipykernel_2725/1684872134.py:47: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return data_df.groupby('event', group_keys=False).apply(compute_moment_matrix)
# /var/folders/78/mghq7lpd3rbcbtn434kbwgdw0000gn/T/ipykernel_2725/1684872134.py:47: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
# ...

# %%
def plot_theta_phi_distributions(orient_data, orient_sim, bins_theta=50, bins_phi=50):
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    
    coords = ['theta', 'phi']
    bins_dict = {'theta': bins_theta, 'phi': bins_phi}
    colors = {'data': 'tab:blue', 'sim': 'tab:orange'}
    
    for i, coord in enumerate(coords):
        for label, orient_df in zip(['data', 'sim'], [orient_data, orient_sim]):
            values = orient_df[coord].dropna().values
            n_events = len(values)

            if n_events == 0:
                continue
            # Define histogram range
            if coord.lower() == 'theta':
                hist_range = (0, 0.5)
            elif coord.lower() == 'phi':
                hist_range = (-np.pi, np.pi)
            else:
                hist_range = (values.min(), values.max())

            # Compute histogram
            counts, bin_edges = np.histogram(values, bins=bins_dict[coord], range=hist_range)
            bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

            # Use normalization factor
            norm_factor = dat_evts if label == 'data' else sim_evts
            norm_counts = counts / norm_factor
            norm_errors = np.sqrt(counts) / norm_factor

            # Find maximum bin location
            if len(norm_counts) > 0:
                max_idx = np.argmax(norm_counts)
                max_bin = bin_centers[max_idx]
                legend_label = f"{label.capitalize()} (max @ {max_bin:.3f})"
            else:
                legend_label = label.capitalize()
            fmt = '-'
            if label.capitalize() == 'Data':
                fmt = 'o'
        
            # Plot
            axes[i].errorbar(bin_centers, norm_counts, yerr=norm_errors, fmt=fmt, label=legend_label, color=colors[label])
            print(max_bin)
        axes[i].set_title(f'{coord.capitalize()} Distribution')
        axes[i].set_xlabel(f'{coord.capitalize()} (radians)')
        axes[i].set_ylabel('Normalized Counts')
        axes[i].legend(fontsize = 10)

    plt.tight_layout()
    plt.show()


plot_theta_phi_distributions(orient_data, orient_sim)
# Out:
# 0.095
# 0.105000004
# 3.0787608005179976
# 2.8274333

# %%
def compute_delta_psi(df):
    # Filter valid entries
    valid = df[['principal_axis_x', 'principal_axis_y', 'principal_axis_z']].dropna()
    vecs = valid[['principal_axis_x', 'principal_axis_y', 'principal_axis_z']].values
    # Normalize vectors
    vecs = vecs / np.linalg.norm(vecs, axis=1)[:, np.newaxis]
    # Mean direction
    mean_dir = np.mean(vecs, axis=0)
    mean_dir /= np.linalg.norm(mean_dir)
    # Compute angular separation
    dot = np.clip(np.dot(vecs, mean_dir), -1.0, 1.0)
    delta_psi = np.arccos(dot)
    return delta_psi, mean_dir

def plot_delta_psi(delta_psi_data, delta_psi_sim, bins=60, max_angle=None):
    # Convert to degrees
    delta_psi_data_deg = np.degrees(delta_psi_data)
    delta_psi_sim_deg = np.degrees(delta_psi_sim)

    # Compute RMS
    rms_data = np.sqrt(np.mean(delta_psi_data_deg ** 2))
    rms_sim = np.sqrt(np.mean(delta_psi_sim_deg ** 2))

    if max_angle is None:
        max_angle = max(np.percentile(delta_psi_data_deg, 99.9),
                        np.percentile(delta_psi_sim_deg, 99.9))
        max_angle = min(max_angle, 20.0)  # limit the range sensibly

    fig, ax = plt.subplots(figsize=(8, 6))

    # Data histogram
    counts_d, bins_d = np.histogram(delta_psi_data_deg, bins=bins, range=(0, max_angle))
    centers_d = (bins_d[:-1] + bins_d[1:]) / 2
    total_d = counts_d.sum()
    norm_d = counts_d / total_d
    errors_d = np.sqrt(counts_d) / total_d

    # Sim histogram
    counts_s, bins_s = np.histogram(delta_psi_sim_deg, bins=bins, range=(0, max_angle))
    centers_s = (bins_s[:-1] + bins_s[1:]) / 2
    total_s = counts_s.sum()
    norm_s = counts_s / total_s
    errors_s = np.sqrt(counts_s) / total_s

    # Plot
    ax.errorbar(centers_d, norm_d, yerr=errors_d, fmt='o', label=f"Data RMS={rms_data:.1f}°")
    ax.errorbar(centers_s, norm_s, yerr=errors_s, fmt='-', label=f"Sim RMS={rms_sim:.1f}°")

    ax.set_xlabel("Angular separation ΔΨ (deg)")
    ax.set_ylabel("Normalized counts")
    ax.legend()
    ax.set_title("Angular distribution [PRELIMINARY]", fontsize=25)
    plt.tight_layout()
    plt.savefig('plots/angular_res.pdf', bbox_inches='tight')
    plt.show()

# Usage
delta_psi_data, mean_dir_data = compute_delta_psi(orient_data)
delta_psi_sim, mean_dir_sim = compute_delta_psi(orient_sim)

plot_delta_psi(delta_psi_data, delta_psi_sim)

# %%
def project_to_z0(cog_df, orient_df):
    """
    Given dataframes with cluster COG and principal axis,
    compute projected (x, y) at z=0 plane for each event.
    
    Parameters:
        cog_df: DataFrame with columns ['event', 'x_cog', 'y_cog', 'z_cog']
        orient_df: DataFrame with columns ['event', 'principal_axis_x', 'principal_axis_y', 'principal_axis_z']
    
    Returns:
        DataFrame with columns ['event', 'x_proj', 'y_proj'] representing intersection point at z=0
    """
    merged = cog_df.merge(orient_df, on='event')

    def compute_projection(row):
        z0 = row['z_cog']
        vz = row['principal_axis_z']
        if vz == 0:
            # Avoid division by zero, no intersection if principal axis parallel to plane
            return pd.Series({'x_proj': np.nan, 'y_proj': np.nan})
        
        t = -z0 / vz
        x_proj = row['x_cog'] + t * row['principal_axis_x']
        y_proj = row['y_cog'] + t * row['principal_axis_y']
        return pd.Series({'x_proj': x_proj, 'y_proj': y_proj})
    
    proj_points = merged.apply(compute_projection, axis=1)
    result = pd.concat([merged['event'], proj_points], axis=1)
    return result

# %%
cog_data = event_cog(data_df, hit_threshold)
cog_sim = event_cog(sim_df, hit_threshold)

# %%
def plot_projected_2d_hist(proj_df, bins=50, range_x=None, range_y=None):
    """
    Plot normalized 2D histogram with error bars of projected (x_proj, y_proj).
    
    Parameters:
        proj_df: DataFrame with columns ['x_proj', 'y_proj']
        bins: int or [int, int], number of bins for x and y
        range_x: tuple (xmin, xmax) or None
        range_y: tuple (ymin, ymax) or None
    """
    x = proj_df['x_proj'].values
    y = proj_df['y_proj'].values
    
    # Remove NaNs
    mask = (~np.isnan(x)) & (~np.isnan(y))
    x = x[mask]
    y = y[mask]
    
    # Compute 2D histogram
    counts, xedges, yedges = np.histogram2d(x, y, bins=bins, range=[range_x, range_y])
    
    # Normalize by total counts
    total = counts.sum()
    if total > 0:
        counts_norm = counts / total
        errors = np.sqrt(counts) / total
    else:
        counts_norm = counts
        errors = np.zeros_like(counts)
    
    # Compute bin centers
    xcenters = (xedges[:-1] + xedges[1:]) / 2
    ycenters = (yedges[:-1] + yedges[1:]) / 2
    
    # Plot with imshow and overlay error as contour or colorbar
    
    plt.figure(figsize=(8,6))
    im = plt.imshow(
        counts_norm.T, origin='lower',
        extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]],
        aspect='auto',
        cmap='viridis'
    )
    plt.colorbar(im, label='Normalized counts')
    plt.xlabel('x_proj')
    plt.ylabel('y_proj')
    plt.title('Projected cluster points (z=0)')
    plt.show()

proj_points_data = project_to_z0(cog_data, orient_data)
plot_projected_2d_hist(proj_points_data, bins=60, range_x=(-20,20), range_y=(-20,20))

proj_points_sim = project_to_z0(cog_sim, orient_sim)
plot_projected_2d_hist(proj_points_sim, bins=60, range_x=(-20,20), range_y=(-20,20))

# %%
def plot_proj_1d_with_fit(proj_data_df, proj_sim_df, bins=100, range_x=(-50,50), range_y=(-50,50)):
    # Extract positions
    x_data = proj_data_df['x_proj'].values
    y_data = proj_data_df['y_proj'].values
    x_sim = proj_sim_df['x_proj'].values
    y_sim = proj_sim_df['y_proj'].values

    # Remove NaNs
    x_data, y_data = x_data[~np.isnan(x_data)], y_data[~np.isnan(y_data)]
    x_sim, y_sim = x_sim[~np.isnan(x_sim)], y_sim[~np.isnan(y_sim)]

    fig, axs = plt.subplots(1, 2, figsize=(15, 8))

    for ax, var_data, var_sim, rng, label in zip(
        axs, 
        [x_data, y_data], 
        [x_sim, y_sim], 
        [range_x, range_y], 
        ['X', 'Y']
    ):
        # Data histogram
        counts_d, bins_d = np.histogram(var_data, bins=bins, range=rng)
        centers_d = (bins_d[:-1] + bins_d[1:]) / 2
        total_d = np.sum(counts_d)
        counts_d_norm = counts_d / total_d
        errors_d = np.sqrt(counts_d) / total_d

        # Sim histogram
        counts_s, bins_s = np.histogram(var_sim, bins=bins, range=rng)
        centers_s = (bins_s[:-1] + bins_s[1:]) / 2
        total_s = np.sum(counts_s)
        counts_s_norm = counts_s / total_s
        errors_s = np.sqrt(counts_s) / total_s

        # Fit data
        try:
            p0_d = [np.max(counts_d_norm), centers_d[np.argmax(counts_d_norm)], np.std(var_data)]
            popt_d, _ = curve_fit(gaussian, centers_d, counts_d_norm, p0=p0_d)
            A_d, mu_d, sigma_d = popt_d
        except RuntimeError:
            A_d, mu_d, sigma_d = 0, 0, 0

        # Fit sim
        try:
            p0_s = [np.max(counts_s_norm), centers_s[np.argmax(counts_s_norm)], np.std(var_sim)]
            popt_s, _ = curve_fit(gaussian, centers_s, counts_s_norm, p0=p0_s)
            A_s, mu_s, sigma_s = popt_s
        except RuntimeError:
            A_s, mu_s, sigma_s = 0, 0, 0

        # Subtract in quadrature for data
        if label == 'X':
            sigma_corr = np.sqrt(max(0, sigma_d**2 - (10.6/np.sqrt(12))**2))
        else:
            sigma_corr = np.sqrt(max(0, sigma_d**2 - 1.44**2))

        # Plot data
        ax.errorbar(centers_d, counts_d_norm, yerr=errors_d, fmt='o', label=f"Data μ={mu_d:.2f}, σ={sigma_corr:.2f}")
        ax.plot(centers_d, gaussian(centers_d, *popt_d), 'b--')

        # Plot sim
        ax.errorbar(centers_s, counts_s_norm, yerr=errors_s, fmt='-', label=f"Sim μ={mu_s:.2f}, σ={sigma_s:.2f}")
        ax.plot(centers_s, gaussian(centers_s, *popt_s), 'r--')
        ax.set_ylim(0,0.1)
        ax.set_xlabel(f'{label} [mm]')
        ax.set_ylabel('Normalized counts')
        ax.legend(loc="upper right")
        ax.set_title(f'Projected {label} Position [PRELIMINARY]', fontsize=21)

    plt.tight_layout()
    plt.savefig('plots/position_res.png', bbox_inches='tight')
    plt.show()

plot_proj_1d_with_fit(proj_points_data, proj_points_sim, bins=100, range_x=(-50,50), range_y=(-50,50))
